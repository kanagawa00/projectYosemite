# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
waseda_username="#######"
keypass="#######"
#search_keyword="もう一つの祖国　戦後７０年"
#keywordlist=["(ワーキングママ+ワーキング母+ワーママ+ワーキングマザー+働くママ+働く母)&(子ども+子育て+保育+育児+ＰＴＡ+児童+保育園+出産+育休+子供+主婦+家事+職場+改革+キャリア+妊娠+共働き+結婚+産む+赤ちゃん)"]
#keywordlist=["戦後７０年・",
#            "（戦後７０年",
#            "戦後７０年：",
#            "もう一つの祖国　戦後７０年　",
#            "戦後７０年、日本の転換点",
#            "円が映す戦後７０年",
#            "７０年目の首相",
#            "ナショナルと戦後の風景",
#            "核といのちを考える",
#            "戦争孤児の７０年",
#            "継ぐ記憶　私たちに戦争を教えてください",
#            "くらし７０年",
#            "もう一つの戦後　日系米国人の７０年"]
keywordlist=["中国&決済&(スマホ+モバイル+QRコード)"]

articles=[]
#f=open("AsahiCheck.txt","w",encoding="utf-8")

#一覧表示&テキストスクレイピングのプログラム
def newsdownload(browser,nl):
    browser.find_element_by_xpath('//input[@name="btnCheckOn"]').click()
    browser.find_element_by_xpath('//input[@name="btnDetail"]').click()
    numlist=browser.find_elements_by_xpath('//td[@class="topic-list"]//nobr') #掲載日
    arealist=browser.find_elements_by_xpath('//td[@class="topic-list"and@align="center"]') #掲載日
    time.sleep(1)
    ttllist=browser.find_elements_by_class_name("font002")
    
    #newslist=browser.find_elements_by_class_name("detail001")
    allnewslist=browser.find_elements_by_xpath('//table[@class="topic-detail"]/tbody/tr/td')
    newslist=[]
    for c in range(int(len(allnewslist)/3)):
        newslist.append(allnewslist[c*3+2])
    
    time.sleep(1)

    datelist=[]
    for i in range(int(len(numlist)/2)):
        datelist.append(str(numlist[i*2].text+numlist[i*2+1].text))

    nolist,daylist,menlist,pagelist,lenlist=[],[],[],[],[]
    for k in range(int(len(arealist)/6)):
        nolist.append(arealist[k*6].text)
        daylist.append(arealist[k*6+2].text)
        menlist.append(arealist[k*6+3].text)
        pagelist.append(arealist[k*6+4].text)
        lenlist.append(arealist[k*6+5].text)
    
    #print("ttlist size:",len(ttllist))
    #print("menlist size:",len(menlist))
    #print("nolist size:",len(nolist))
    #print("datelist size:",len(datelist))
    #print("newslist size:",len(newslist))
    #print("daylist size:",len(daylist))
    #print("pagelist size:",len(pagelist))
    #print("lenlist size:",len(lenlist))
    
    for no,date,ttl,news,day,men,page,size in zip(nolist,datelist,ttllist,newslist,daylist,menlist,pagelist,lenlist):
        if news.text.startswith("※著作権などの関係で本文を表示できません。"):
            pass
        else:
            nl.append([no,date,ttl.text,day,men,page,size,news.text])
            #f.write("<H1>"+date+"</H1>"+"\n")
            #f.write("<H2>"+ttl.text+"</H2>"+"\n")
            #f.write("\n"+news.text+"\n\n\n")
            #print("■■■■■■■■■■■■■■■■■■")
    time.sleep(2)
    browser.find_element_by_xpath('//img[@alt="検索一覧画面へ戻る"]').click()
    time.sleep(1)
    try:
        browser.find_element_by_name("next").click()
    except:
        pass


def getpage(browser,search_keyword,newsdata):
#早稲田検索ページを開ける
    #browser.get("http://waseda.summon.serialssolutions.com/jp/search?q=%E6%9C%9D%E6%97%A5%E6%96%B0%E8%81%9E&l=jp#!/search?ho=t&l=jp&q=%E6%9C%9D%E6%97%A5%E6%96%B0%E8%81%9E")
    #time.sleep(3)
    #targetlink=browser.find_element_by_xpath('//*[@ng-bind="::item.bet.title"]')
    #targetlink.click()
    #新しいページでログインする
    #allHandles = browser.window_handles
    #for handle in allHandles:
    #    if browser.title.find("EZproxy") == -1:
    #        browser.switch_to_window(handle)
    
    #elem_user = browser.find_element_by_name("user")
    #elem_user.send_keys(waseda_username)
    #elem_pwd = browser.find_element_by_name("pass")
    #elem_pwd.send_keys(keypass)
    #browser.find_element_by_xpath('//*[@type="submit"]').click()
    time.sleep(2)
    browser.get("http://database.asahi.com/")
    browser.find_element_by_xpath('//*[@alt="ログイン（Login）へ"]').click()
    time.sleep(3)
    browser.switch_to_frame("Introduce")
    browser.find_element_by_xpath('//input[@id="chkShishi2"]').click()
    browser.find_element_by_xpath('//input[@id="chkShishi3"]').click()
    browser.find_element_by_xpath('//input[@id="chkShishi4"]').click()
    #検索キーワードを入力する
    elem_inkw = browser.find_element_by_name("txtWord")
    elem_inkw.send_keys(search_keyword)
    
    browser.find_element_by_xpath('//input[@id="rdoSrchMode2"]').click() #詳細検索
    #browser.find_element_by_xpath('//input[@id="rdoSrchItem3"]').click() #見出しだけ検索
    browser.find_element_by_xpath('//input[@id="chkHochi2"]').click() #地方紙
    browser.find_element_by_xpath('//input[@id="chkIssueS2"]').click()
    browser.find_element_by_xpath('//input[@id="chkIssueS3"]').click()
    browser.find_element_by_xpath('//input[@id="chkIssueS4"]').click()
    browser.find_element_by_xpath('//input[@id="chkIssueS5"]').click()
    Select(browser.find_element_by_name("cmbDspNum")).select_by_value("100") 

    Select(browser.find_element_by_name("cmbIDFy")).select_by_value("2012") 
    Select(browser.find_element_by_name("cmbIDFm")).select_by_value("01") 
    Select(browser.find_element_by_name("cmbIDFd")).select_by_value("01")
    Select(browser.find_element_by_name("cmbIDTy")).select_by_value("2018") 
    Select(browser.find_element_by_name("cmbIDTm")).select_by_value("12") 
    Select(browser.find_element_by_name("cmbIDTd")).select_by_value("09")

    time.sleep(1)
    browser.find_element_by_xpath('//input[@value="検索実行"]').click()

    #ページの切り替え
    w_start=1
    w_news=browser.find_element_by_xpath('//*[@class="fontcolor001"]')
    w_page=int(w_news.text)//100+1
    while w_start<=w_page:
        newsdownload(browser,newsdata)
        w_start+=1

    #browser.close()

browser = webdriver.Chrome()
for keyword in keywordlist:
    getpage(browser,keyword,articles)

browser.quit()
#f.close()
       
#データフレーム構築
df = pd.DataFrame(articles,columns=["No","時間","タイトル","朝夕刊","面","ページ","文字数","記事内容"])
#df.to_csv("AsahiCheck2.csv",encoding="utf-8",sep="\t", index=False)
df.to_excel('AsahiCheck.xlsx', sheet_name='sheet1')
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:108: DeprecationWarning: use driver.switch_to.frame instead
#        No           時間                                               タイトル 朝夕刊  \
# 0   00001  2018年12月05日                          （チャイナスタンダード）次世代通貨、新たな覇権の芽  朝刊
# 1   00002  2018年12月02日         （平成経済）第５部・リーマンの衝撃：１１　リーマン一部買収、光と影＝訂正・おわびあり  朝刊
# 2   00003  2018年11月28日                     「ウィーチャット」と決済提携　ＬＩＮＥ、中国人客取り込み狙う  朝刊
# 3   00004  2018年11月23日        中国の料理店、進む自動化　人件費が急騰／衛生面ＰＲも　ロボットが炒めて、揚げて、運んで  朝刊
# 4   00005  2018年11月22日                         ソフトバンク、９０００人配転へ　新分野に従業員半数超  朝刊
# 5   00006  2018年10月27日                日中経済、「補完」を重視　第三国協力・技術革新・金融・高齢化　首脳会談  朝刊
# 6   00007  2018年10月25日                                  （経済気象台）キャッシュレス化の旗  朝刊
# 7   00008  2018年10月17日                  おさい銭、いつでも電子決済　中国系参拝者増え　栃木・日光二荒山神社  朝刊
# 8   00009  2018年10月16日                       （時時刻刻）消費増税、進まぬ準備　再々延期、業者は不安視  朝刊
# 9   00010  2018年10月07日              グローブ２１０号＜テクノロジーの世紀＞〈４〉中国はデータで世界を征するのか  朝刊
# 10  00011  2018年10月07日                       （もっと教えて！ドラえもん）遊園地に海外のお客、いっぱい  朝刊
# 11  00012  2018年09月12日                ＱＲ決済、群雄割拠　専用読み取り機不要、手数料低め　中小店舗に浸透狙う  朝刊
# 12  00013  2018年09月11日                      郵便局もキャッシュレス化　カードやスマホで決済　２０年導入  朝刊
# 13  00014  2018年09月05日                          （ニュースＱ３）キャッシュレス化、喜んでばかりは…  朝刊
# 14  00015  2018年08月31日                 （けいざい＋）決済情報集め、急ぐ銀行　キャッシュレス化、ＩＴ追いかけ  朝刊
# 15  00016  2018年08月31日                                      （経済気象台）電子少額決済  朝刊
# 16  00017  2018年08月22日              （夏の集中講座ミライ×ヒト　６時間目）新人権宣言　情報社会、規制が自由守る  朝刊
# 17  00018  2018年08月05日  グローブ２０８号＜Ｒｅ：ｓｅａｒｃｈ＞仮想通貨を買って、手放す日に気づいたこと　ＧＬＯＢＥ記...  朝刊
# 18  00019  2018年07月20日                        スマホ配車、大阪で実証実験　ＳＢ、秋にも中国大手と開始  朝刊
# 19  00020  2018年07月20日                                （経済気象台）キャッシュレス化への懸念  朝刊
# 20  00021  2018年07月18日                     （聞きたい）スマホ決済、どう広める？　ＬＩＮＥ社長・出沢剛氏  朝刊
# 21  00022  2018年07月12日                            対中制裁、支える世論　米議会、トランプ氏と同調  朝刊
# 22  00023  2018年07月07日  （書評）『ビットコインはチグリス川を漂う　マネーテクノロジーの未来史』　デイヴィッド・バーチ〈著〉  朝刊
# 23  00024  2018年05月11日                              日中協力、経済界は歓迎　海外市場拡大に期待  朝刊
# 24  00025  2018年05月01日               （チャイナスタンダード）幅を利かす中国的価値観　「カラー革命」敵視で共鳴  朝刊
# 25  00026  2018年04月24日                    ローソン、会計は手元でピッ　レジ並ばずスマホで、都内３店で実験  朝刊
# 26  00027  2018年04月14日                                （経済気象台）キャッシュレス社会の功罪  朝刊
# 27  00028  2018年03月31日         （フロントランナー）ＩＴ芸術家、マックス・ホーキンスさん　ソフトまかせの出会い重ねて  朝刊
# 28  00029  2018年03月04日           グローブ２０３号＜デジタルプライバシー＞加速する中国　「究極の便利さ」と「監視」  朝刊
# 29  00030  2018年02月21日             （あのとき・それから）１９９４年　ＱＲコードの誕生　情報化時代を読み取り進化  夕刊
# ..    ...          ...                                                ...  ..
# 42  00043  2017年10月25日                           中国、ひずみ映すネット出前　ＧＤＰ高成長率の陰で  朝刊
# 43  00044  2017年08月19日                   （東洋経済の眼）ＩＴ中国「金融的飛躍」　政府の監督強化で停滞懸念  朝刊
# 44  00045  2017年08月03日           （けいざい＋　ＷＯＲＬＤ）シェア自転車、中国快走　スマホで解錠・利用登録は１億人  朝刊
# 45  00046  2017年07月02日                             グローブ１９５号＜世界の書店から＞北京、パリ  朝刊
# 46  00047  2017年06月18日             （書評）『金融ｅ時代　中国における金融デジタル化の現在と未来』　万建華〈著〉  朝刊
# 47  00048  2017年05月15日                                       ライフスタイル、上海は今  朝刊
# 48  00049  2017年04月06日           ビットコイン身近に？　ビックカメラ、一部店舗で導入へ　決済手段、小売りや飲食でも  朝刊
# 49  00050  2017年03月23日                 （ザ・コラム）中国とビットコイン　国家の管理、すり抜ける民　吉岡桂子  朝刊
# 50  00051  2017年01月30日                          （カイシャの進化）ＬＩＮＥ　異能が集えば、成長曲線  朝刊
# 51  00052  2017年01月27日                      スマホで決済、広がるアリペイ　春節の中国人客狙い、２万店で  朝刊
# 52  00053  2016年09月09日                     ｉＰｈｏｎｅ７、異例の日本重視　新型機種、「Ｓｕｉｃａ」対応  朝刊
# 53  00054  2016年07月22日                  （けいざい＋　新話）ＬＩＮＥ上場：３　事業拡張、スマホの「玄関」に  朝刊
# 54  00055  2016年07月16日                        ＬＩＮＥ、２年かけ上場　アジアに投資「好機逃す」指摘も  朝刊
# 55  00056  2016年06月04日                       電子マネー、中国席巻　取引額１５０兆円規模、日本の３０倍  朝刊
# 56  00057  2016年01月24日                      （ビジネス）『ＦｉｎＴｅｃｈ革命』　日経コンピュータ〈編〉  朝刊
# 57  00058  2015年03月03日                         （時時刻刻）スマホ２強、頂上決戦　サムスン×アップル  朝刊
# 58  00059  2015年03月02日                新スマホ、サムスン反撃へ　ｉＰｈｏｎｅ６に対抗　高性能と高級感を前面に  夕刊
# 59  00060  2014年11月16日  グローブ１４７号＜いまを読む＞新興国経済、新指導者に期待　ＩＴやインフラ投資に活路　ティモシ...  朝刊
# 60  00061  2014年11月05日                             携帯大手、多角化に力　格安スマホ台頭に危機感  朝刊
# 61  00062  2014年09月11日            アップル、勝負の時　神話再現へ、細部に「らしさ」　ウオッチ・ｉＰｈｏｎｅ６発表  朝刊
# 62  00063  2014年09月10日                        アップルウオッチ、手腕いかに　「ジョブズ後」初の新分野  夕刊
# 63  00064  2014年07月27日                  （波聞風問）ビットコイン健在　中国、せめぎあう規制と自由　吉岡桂子  朝刊
# 64  00065  2014年03月19日                                             ニュースでＱ  朝刊
# 65  00066  2014年02月26日                    スマホ端末、アイデア勝負　新興メーカーが続々　スペイン・ＭＷＣ  朝刊
# 66  00067  2014年02月14日                ネット不正送金、運び屋介し洗浄　隠し口座８０００万円、家電に化け中国へ  朝刊
# 67  00068  2014年02月13日                    中古買い付け、万来中国人　「日本なら本物」ブランド品求め東京へ  夕刊
# 68  00069  2012年05月08日           金環日食ショー、感動つなごう　「誰かに伝えたくなるはず」　朝日新聞ＤＩＧＩＴＡＬ  朝刊
# 69  00070  2012年05月01日             英語力、ニュースで磨こう　「Ｂｉｚ　Ｅｎｇｌｉｓｈ」　朝日新聞ＤＩＧＩＴＡＬ  朝刊
# 70  00071  2012年04月26日                                             ニュースでＱ  朝刊
# 71  00072  2012年04月20日                        「銀聯」で中国客呼び込め　カード各社、取扱店の拡大に力  朝刊
#
#            面  ページ      文字数                                               記事内容
# 0        ２総合  002  02578文字  ▼１面参照\n\n■アリペイ、新興国に照準　スマホ決済\n中国が狙うのは、現実通貨の世界で米...
# 1        経済総  004  02836文字  ２００８年９月のリーマン・ショックの発端となった米金融大手リーマン・ブラザーズの経営破綻（は...
# 2        ２経済  008  00506文字  ＬＩＮＥと中国のＩＴ大手テンセント（本社・深セン）は２７日、日本での決済サービスで提携すると...
# 3        １経済  009  00837文字  中国のレストランで自動化が進んでいる。経済成長による人件費高騰に加え、衛生意識の高まりも自動...
# 4        ２経済  008  00666文字  ソフトバンクは、数年内に１万７千人の従業員のうち９千人をグループの新ビジネスに配置転換するこ...
# 5        ４総合  004  04540文字  ２６日の日中首脳会談では、両国間の今後の経済協力の方向性が固まった。主な柱は、第三国協力▽イ...
# 6        ２商況  011  00706文字  政府がキャッシュレス化推進の旗を振っている。カードやスマホで決済できれば、現金を持ち歩くリス...
# 7        ２社会  038  00498文字  栃木県日光市の日光二荒山（ふたらさん）神社は、参拝者がスマートフォンの電子決済で、いつでもさ...
# 8        ２総合  002  02325文字  安倍晋三首相が１５日、来年１０月の消費増税に備えた対策の策定を指示した背景には、予定通りの実...
# 9     グローブ６面  006  02510文字  「女性　年齢：２５　楽しそう」「男性　年齢：２４　落ち着いている」\n６月、上海市であった家...
# 10      東特集Ｄ  018  02104文字  みんな大好（だいす）きな遊園地（ゆうえんち）。近年（きんねん）は海外（かいがい）からも多（お...
# 11       ２経済  006  01192文字  ＱＲコードを使った決済サービスが続々登場している。大手からベンチャーまで群雄割拠の様相で、主...
# 12       ２経済  008  00316文字  日本郵便は１０日、全国の郵便局に２０２０年から順次、現金を使わないで支払いできるキャッシュレ...
# 13       ３社会  025  01357文字  電子マネーやクレジットカードなど、現金なしで買い物をする「キャッシュレス化」が急速に進んでい...
# 14       １経済  009  01534文字  細身のジーンズをはく女性は、スマートフォン保険を成約しやすい――。\n中国ネット通販最大手の...
# 15       ２商況  009  00712文字  ＩＴの発展でスマホによる電子少額決済が可能になった。スマホにカード機能を持たせ決済に使う。現...
# 16      文化文芸  029  02157文字  「人は自由かつ権利において平等なものとして生まれ、また、存在する」\n◇\n１７８９年のフラ...
# 17    グローブ８面  008  08564文字  私がビットコインを買ったのは、６月２０日のことだった。ニュースでもおなじみの仮想通貨。でも聞...
# 18       ２経済  009  00557文字  中国の配車大手、滴滴出行（ディディチューシン）とソフトバンクは１９日、スマートフォンを使った...
# 19       ２商況  012  00719文字  経済産業省の報告書によれば、政府はキャッシュレス決済比率を２０２５年までに４割に引き上げると...
# 20       金融経  010  01127文字  ■対応の店増やし、便利さ実感促す\n中国ではスマートフォン決済が広まっています。普及の鍵にな...
# 21       １経済  009  01849文字  トランプ米政権が１０日公表した中国に対する総額２千億ドル（約２２兆円）分の追加制裁の関税措置...
# 22       読書３  017  00921文字  ■取引履歴の透明化で時代回帰？\n――自販機にて。\n孫娘「おばあちゃん、それ１円玉だよっ」...
# 23       １経済  007  01244文字  日中首脳会談で合意された経済協力の強化について、日本の経済界からは一夜明けた１０日、歓迎する...
# 24       ２総合  002  03128文字  ▼１面参照\n\n「今年は『カラー革命』失敗の年だ」。カンボジアの正月を控えた４月９日、首相...
# 25       ２経済  006  00967文字  ローソンは２３日、利用者にスマートフォンで代金を支払ってもらう「ローソンスマホペイ」の実証実...
# 26       ２商況  014  00725文字  先日中国から来日した知人が「なぜ日本ではまだ現金が幅をきかせているのか？」と不思議がっていた...
# 27  週末ｂｅ・ｂ０１  001  01192文字  待ち合わせは、米フロリダ州マイアミ市の外れにある新興宗教「サイエントロジー」の集会所だった。...
# 28    グローブ５面  005  00982文字  スマートフォンの世界出荷台数で、中国メーカーは韓国サムスン電子や米アップルに迫る勢いだ。中国...
# 29  夕刊ｂｅ水曜１面  004  02627文字  （平成６年）\n\n商品のパッケージや街中のポスター、自動販売機、航空券など、さまざまなとこ...
# ..       ...  ...      ...                                                ...
# 42       １経済  009  01260文字  習近平（シーチンピン）政権が２期目を迎える中国経済。２４日に閉幕した共産党大会の期間中に発表...
# 43       ５商況  008  00636文字  中国でＩＴ（情報技術）による金融の革新が加速しています。足元では大手国有銀行とネット企業の提...
# 44       １経済  007  01449文字  かつては自転車王国だった中国も、今や米国を抜いて世界最大の自動車市場。そんな中国で自転車ブー...
# 45   グローブ１４面  014  03027文字  ■＜北京の書店から＞党政治の腐敗を暴く\n「今日、現金を見たのは初めてですよ」\n北京の大型...
# 46       読書３  013  00472文字  中国におけるフィンテック（金融ＩＴ）の拡大は、北欧と並び世界最速ペースで進んでいる。特にモバ...
# 47       ２外報  006  00901文字  １４億近い人口を抱え、いまなお年率６％台後半の経済成長を続ける中国。国内の発展は目覚ましく、...
# 48       １経済  009  01379文字  仮想通貨「ビットコイン」＝キーワード＝の利用を広げる動きが出てきた。家電量販大手のビックカメ...
# 49    オピニオン２  016  01634文字  仮想通貨ビットコインの市場が大揺れに揺れている。震源地は、中国である。\n「サトシ・ナカモト...
# 50       １経済  004  03012文字  対話アプリ大手ＬＩＮＥ（ライン）で働いていた嘉戸（かど）彩乃さん（３１）に「社長にならない？...
# 51       １経済  007  00557文字  中華圏最大の祝日・春節（旧正月）の連休が２７日から始まるのを前に、中国のスマートフォン（スマ...
# 52       ３総合  003  01533文字  米アップルは、１６日に発売する新型スマートフォン「ｉＰｈｏｎｅ（アイフォーン）７」「７プラス...
# 53       １経済  009  01430文字  スマートポータル――。対話アプリ大手のＬＩＮＥ（ライン）は最近、自らのビジネスをこう表現し始...
# 54       １経済  009  01666文字  スマートフォンの対話アプリを提供するＬＩＮＥ（ライン）が１５日、東京証券取引所第１部に上場し...
# 55       ２経済  008  01759文字  中国に驚異的な速さで、本格的な電子マネー時代が訪れつつある。ネット通販から始まったＩＴ大手の...
# 56       読書４  016  00583文字  『ＦｉｎＴｅｃｈ（フィンテック）革命』　日経コンピュータ〈編〉\n\n■金融・ＩＴが融合する...
# 57       ２総合  002  02503文字  世界で大人気の米アップル「ｉＰｈｏｎｅ６」に対抗して、世界シェアでトップの韓国サムスン電子が...
# 58       １総合  001  00716文字  スマートフォンのシェアで世界首位の韓国サムスン電子は１日、スペイン・バルセロナで新型モデルを...
# 59    グローブ１０  010  01761文字  ２００８年の金融危機から６年。危機直後に世界経済を支えた新興国はいま、景気減速に直面している...
# 60       ２経済  009  01326文字  大手携帯３社が、競争に勝つための次の一手を探している。４日までに出そろった２０１４年９月中間...
# 61       ３総合  003  01705文字  米アップルの久々の新型製品となる腕時計型端末「アップルウオッチ」が９日（日本時間１０日未明）...
# 62       １総合  001  01736文字  米アップルは９日（日本時間１０日未明）、腕時計型の端末「アップルウオッチ」を来年初めに売り出...
# 63       １経済  004  01124文字  波聞風問（はもんふうもん）\n\n上海の繁華街にあるオフィスビル６階の一室。４０人ほどの若者...
# 64       教育１  034  00441文字  最新ニュースからのクイズです。Ｑ１の（　）は新しく日本に参入したＩＴサービス。Ｑ２の（　）は...
# 65       ２経済  010  01367文字  スペイン・バルセロナで開催中の携帯電話関連で世界最大の見本市「モバイル・ワールド・コングレス...
# 66       １社会  039  01509文字  インターネットバンキングの口座から不正送金された被害金を「隠し口座」に移し替えたとして、警視...
# 67       １総合  001  01436文字  東京都内の中古ブランド品店で、常連の中国人が増えている。転売目的の買い付け人だ。日本人の鑑定...
# 68      東特集Ｄ  031  03623文字  本州で１２９年ぶりとなる２１日の金環日食で、朝日新聞の電子版「朝日新聞デジタル」は列島を縦断...
# 69      東特集Ｄ  020  02958文字  新聞を読みながら、英語の力を磨いてみませんか――。朝日新聞の電子版「朝日新聞デジタル」は４月...
# 70       教育１  033  00410文字  最新ニュースからのクイズです。Ｑ１の（　）には携帯メールに関係する言葉が、Ｑ２の（　）には中...
# 71       １経済  006  00996文字  日本に来る中国人観光客を取り込もうと、国内クレジットカード各社が、中国人が使う「銀聯（ぎんれ...
#
# [72 rows x 8 columns]
