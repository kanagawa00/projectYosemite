# %%
'''
20190112 機能追加「各地域版を個別に選択する」
'''

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import pandas as pd

#search_keyword="GMO"

articles=[]
#f=open("C_YomiuriChecker1.txt","w",encoding="utf-8")

#一覧表示&テキストスクレイピングのプログラム
def newsdownload(browser,nl):
    browser.find_element_by_xpath('//*[@onclick="toggleCheck(document.forms[\'search\'], \'yomiuriNewsArticleDto.chkboxCollectiveIndication\', true);return false;"]').click()
    browser.find_element_by_xpath('//*[@onclick="validateAllDisplayCheckBox(\'yomiuriNewsArticleDto.chkboxCollectiveIndication\', \'search\', new Array(\'表示チェックが選択されていません。\', \'一括表示できる件数は20件までです。続行しますか？\'), \'yomiuriNewsArticle.action?allDisplayFlg=true\');return false;"]').click()
    datelist=browser.find_elements_by_xpath('//*[@style="width:80px;vertical-align:middle;"]')
    alllist=browser.find_elements_by_xpath('//table[@class="contentsTable"]/tbody/tr')
    daynightlist,arealist,pagelist,sizelist=[],[],[],[]
    for tmps in alllist:
        tmps=str(tmps.text)
        tlist=tmps.split(" ")
        daynightlist.append(tlist[3])
        arealist.append(tlist[4])
        pagelist.append(tlist[5])
        sizelist.append(tlist[6])

    ttllist=browser.find_elements_by_class_name("wp50")
    newslist=browser.find_elements_by_class_name("mb10")
    for date,ttl,news,daynight,area,page,size in zip(datelist,ttllist,newslist,daynightlist,arealist,pagelist,sizelist):
        #if daynight.startswith("東京朝刊") or daynight.startswith("東京夕刊"):
            #print(daynight.text)
            #print(date.text)
            #print(ttl.text)
            #print(news.text)
            #f.write("<H1>"+date.text+"</H1>"+"\n")
            #f.write("<H2>"+ttl.text+"</H2>"+"\n")
            #f.write("\n"+news.text+"\n\n\n")
            #print("■■■■■■■■■■■■■■■■■■")
        nl.append([date.text,ttl.text,daynight,area,page,size,news.text])
        #else:
        #    pass
    time.sleep(3)
    browser.find_element_by_xpath('//*[@onclick="execute(document.forms[\'article\'], \'yomiuriNewsPageSearchList.action\');return false;"]').click()
    time.sleep(1)
    browser.find_element_by_class_name("nextPage").click()

#早稲田検索ページを開ける
def getpage(browser,search_keyword,newsdata):
    #browser.get("http://waseda.summon.serialssolutions.com/jp/search?q=%E8%AA%AD%E5%A3%B2%E6%96%B0%E8%81%9E&l=jp#!/search?ho=t&l=jp&q=%E8%AA%AD%E5%A3%B2%E6%96%B0%E8%81%9E")
    #time.sleep(3)
    #targetlink=browser.find_element_by_xpath('//*[@ng-bind="::item.bet.title"]')
    #targetlink.click()
    #print("1.検索完了")
    #新しいページでログインする
    #allHandles = browser.window_handles
    #for handle in allHandles:
    #    if browser.title.find("EZproxy") == -1:
    #        browser.switch_to_window(handle)
    #elem_user = browser.find_element_by_name("user")
    #elem_user.send_keys("tsh")
    #elem_pwd = browser.find_element_by_name("pass")
    #elem_pwd.send_keys("Aragaki01!")
    #browser.find_element_by_xpath('//*[@type="submit"]').click()
    browser.get("https://database.yomiuri.co.jp/rekishikan/")
    time.sleep(2)
    #print("2.ログイン完了")
    #読売歴史館に入った後、検索モードを平成モードに切り替える
    browser.get("https://database-yomiuri-co-jp.ez.wul.waseda.ac.jp/rekishikan/yomiuriNewsSearch.action")
    time.sleep(1)
    #検索キーワードを入力する
    elem_inkw = browser.find_element_by_name("yomiuriNewsSearchDto.txtWordSearch")
    elem_inkw.send_keys(search_keyword)
    
    browser.find_element_by_xpath('//*[@value="100"]').click() #100件表示

    browser.find_element_by_class_name("choiceArea1Open").click()  #個別に選択する
    browser.find_element_by_xpath(u'//*[@title="全国版"]').click() #全国版
    #browser.find_element_by_xpath(u'//*[@title="地域版"]').click() #地域版
    
    #各地域版を個別に選択する
    #browser.find_element_by_xpath(u'//*[@title="各地域版を個別に選択する"]').click()
    ##関東
    #browser.find_element_by_xpath(u'//*[@title="茨城"]').click()
    #browser.find_element_by_xpath(u'//*[@title="栃木"]').click()
    #browser.find_element_by_xpath(u'//*[@title="群馬"]').click()
    #browser.find_element_by_xpath(u'//*[@title="埼玉"]').click()
    #browser.find_element_by_xpath(u'//*[@title="千葉"]').click()
    #browser.find_element_by_xpath(u'//*[@title="東京"]').click()
    #browser.find_element_by_xpath(u'//*[@title="神奈川"]').click()
    
    #期間
    browser.find_element_by_id("txtSYear").send_keys("2008")
    browser.find_element_by_id("txtSMonth").send_keys("1")
    browser.find_element_by_id("txtSDay").send_keys("1")
    browser.find_element_by_id("txtEYear").send_keys("2018")
    browser.find_element_by_id("txtEMonth").send_keys("12")
    browser.find_element_by_id("txtEDay").send_keys("31")
    time.sleep(5)
    browser.find_element_by_id("yomiuriNewsSubmitButton").click()
    #print("3.検索完了")
    #print("■■■■■■■■■■■■■■■■■■")

    #ページの切り替え
    w_start=1
    w_news=browser.find_element_by_xpath('//*[@class="heiseiOperationLeft"]//*[@class="flL"]')
    w_news=w_news.text.replace(" 件中","")
    w_page=int(w_news)//100+1
    while w_start<=w_page:
        newsdownload(browser,newsdata)
        w_start+=1
#print("4.done")

#keywordlist=["(ワーキングママ OR ワーキング母 OR ワーママ OR ワーキングマザー OR 働くママ OR 働く母) AND (子ども OR 子育て OR 保育 OR 育児 OR ＰＴＡ OR 児童 OR 保育園 OR 出産 OR 育休 OR 子供 OR 主婦 OR 家事 OR 職場 OR 改革 OR キャリア OR 妊娠 OR 共働き OR 結婚 OR 産む OR 赤ちゃん)"]
#keywordlist=["［戦後７０年",
#             "［社会保障　戦後７０年］",
#             "［証言　大連の抑留］",
#             "［７０年後の返信］",
#             "［ニッポンの貢献　戦後７０年］",
#             "［語る］戦後７０年",
#             "［日米関係　戦後７０年］"]
keywordlist=["人工知能"]

browser = webdriver.Chrome()
for keyword in keywordlist:
    getpage(browser,keyword,articles)
browser.quit()
#データフレーム構築
df = pd.DataFrame(articles,columns=["時間","タイトル","地域","面","ページ","文字数","記事内容"])
#df.to_csv("C_YomiuriChecker1.csv",encoding="utf-8",sep="\t", index=False)
df.to_excel('YomiuriCheck_AI.xlsx', sheet_name='sheet1')
df
# Out:
#               時間                                   タイトル      地域    面  ページ  \
# 0     2018.12.31    法律翻訳にＡＩ活用へ　「言い回し」蓄積→処理速度向上　有識者会議で検討    東京朝刊   二面  02頁
# 1     2018.12.30  平成時代　深掘り世論調査特集（上）ネット社会　光と影　情報　豊かさの象徴に    東京朝刊  朝特Ｄ  08頁
# 2     2018.12.30                           ［編集手帳］１２月３０日    東京朝刊   一面  01頁
# 3     2018.12.30                 ＡＩで安心の街づくり　ＮＴＴ、米で事業拡大へ    東京朝刊   政経  04頁
# 4     2018.12.29             中国　ベンチャー育成に注力　アニス・ウッザマン氏４３    東京朝刊   解説  09頁
# 5     2018.12.29     株　高速取引で乱高下　２０１８年日米相場　ＡＩ　ニュース連動で即売買    東京朝刊   Ａ経  08頁
# 6     2018.12.28             ［論点］公共政策　ＡＩが開く未来　広井良典氏（寄稿）    東京朝刊   解説  11頁
# 7     2018.12.28       ［いのち守る］児童相談所の今（中）「特別な日」毎年メール（連載）    東京朝刊   ２社  28頁
# 8     2018.12.28    新たな１００年　米中へ軸足　合計売上高　日本の水準目指す　パナソニック    大阪朝刊   Ａ経  07頁
# 9     2018.12.27             「官製春闘」転換点に　首相賃上げ要請　財界意向に配慮    東京朝刊   Ａ経  09頁
# 10    2018.12.27                アップル　全米で人材獲得　事業多様化　戦略転換    東京朝刊   Ｂ経  08頁
# 11    2018.12.27                新興企業　衛星打ち上げ　２２年までに５０基計画    東京夕刊  夕三面  03頁
# 12    2018.12.26        ［先生の相談室］現状に満足　夢見ない生徒　課題に立ち向かい育む    東京朝刊  教育セ  17頁
# 13    2018.12.25   ［文芸月評］綿矢りささん　最先端　金原ひとみさん　王道　芥川賞から１４年    東京朝刊   文化  11頁
# 14    2018.12.25           ［すてきＬＩＦＥ］電子工作に夢中　伸び盛り　若宮正子さん    東京朝刊  安心Ｃ  19頁
# 15    2018.12.25    旧財閥中心　転換期　経済同友会　小林喜光氏　関西経済連合会　松本正義氏    東京朝刊   Ａ経  08頁
# 16    2018.12.23    読書委員が選ぶ「２０１８年の３冊」　年を越す前にぜひ読むべき本＝その１    東京朝刊  書評Ｂ  12頁
# 17    2018.12.22            ２０１９年度予算案閣議決定　主な事業のポイント＝その２    東京朝刊  朝特Ｄ  14頁
# 18    2018.12.22                            夫婦円満へ「まず共感」    東京朝刊   ３社  35頁
# 19    2018.12.22                      将棋界　戦国時代　羽生伝説　区切り    東京朝刊   ２社  36頁
# 20    2018.12.22               日本医学会シンポジウム「ＡＩと医療の現状と課題」    東京夕刊   健康  06頁
# 21    2018.12.22      若手台頭　新時代に　第３１期竜王戦　第７局　羽生伝説　一つの区切り    西部朝刊  西２社  36頁
# 22    2018.12.22    羽生時代から戦国時代へ　広瀬八段　竜王奪取　若手台頭　タイトル分け合う    大阪朝刊   ２社  38頁
# 23    2018.12.21        雇われずに仕事「ギグ・エコノミー」　「私らしい」働き方　光と影    東京朝刊   Ｃ経  06頁
# 24    2018.12.21      ［改革・開放４０年］変わる社会（１）党への忠誠　信仰も束縛（連載）    東京朝刊   外Ｂ  08頁
# 25    2018.12.20              ［物流新潮流］（上）人手不足　迫られる変革（連載）    東京朝刊   Ａ経  09頁
# 26    2018.12.20          ［スキャナー］ソフトバンク株　低調　携帯上場２．６兆円調達    東京朝刊   三面  03頁
# 27    2018.12.20            データ流通圏　欧米と連携　首相　ＩＴ政策大綱反映を指示    東京朝刊   二面  02頁
# 28    2018.12.20           ＡＩ活用「スマート養豚」　無人でも体調管理　日本ハムなど    大阪朝刊   Ｂ経  08頁
# 29    2018.12.20           ［検証　大村流］（上）減税基金で生産力回復（連載）＝中部    中部朝刊  中２社  34頁
# ...          ...                                    ...     ...  ...  ...
# 2288  2011.11.05   国立情報学研「ドラえもん」計画　人工知能　東大合格目指せ　１０年後目標に    東京夕刊  夕社会  13頁
# 2289  2011.10.08                          ［情報ディスク］１０月８日    東京朝刊   家計  23頁
# 2290  2011.10.04                         「棋士の思考」米長会長が講座    東京朝刊   ３社  37頁
# 2291  2011.02.21           人工知能　人間超える？　意識を移植　肉体滅んでも「不死」    東京朝刊   外Ｂ  07頁
# 2292  2011.01.15                クイズ王ＶＳスパコン　音声で問答　米番組で来月    東京夕刊  夕２社  14頁
# 2293  2011.01.04     ［アトムの子どもたち］（２）心やさしい癒やし系いたら…（連載）＝中部    中部朝刊  中社会  29頁
# 2294  2011.01.03               ［宇宙へ］（１）２０１５年　月面に日の丸（連載）    大阪朝刊   科学  33頁
# 2295  2010.09.21          キヤノン　次の成長分野、ロボット狙う　日本の「お家芸」活用    東京朝刊   Ａ経  09頁
# 2296  2010.09.21                  キヤノン　介護ロボ参入　デジカメ技術を活用    東京朝刊   一面  01頁
# 2297  2010.09.20    ［究める］生命科学界に新風　上田泰己・理化学研究所プロジェクトリーダー    大阪朝刊   科学  11頁
# 2298  2010.06.06             ［ポケットに１冊］「カオスの紡ぐ夢の中で」金子邦彦著    東京朝刊  書評Ｃ  11頁
# 2299  2010.05.07     ［教育ルネサンス］慶大ＳＦＣ２０年（７）地元の熟練農家に学ぶ（連載）    東京朝刊  教育Ａ  22頁
# 2300  2010.05.03           ロボカップジャパン　大阪で開幕　我こそ自律型ロボＮｏ．１    大阪朝刊   社会  23頁
# 2301  2010.02.22           「アイアムアヒーロー」花沢健吾さん　「ヘタレ」の怒り爆発    東京夕刊  夕書評  12頁
# 2302  2010.01.24                  ［よみうり生活本舗］笑いの輪　もっと広がれ    西部朝刊  西女性  15頁
# 2303  2009.09.08           ［シネマ考現楽］無名の主人公、最新ＣＧ…　時代劇に新感覚    大阪夕刊  夕ラジ  13頁
# 2304  2009.02.10          ［生老病死の旅路］小松左京さん　生命起源の謎、説明できそう    東京夕刊  夕文化  05頁
# 2305  2009.01.01                     元日第２部　新春ＢＳ・ＣＳお薦め番組  東京朝刊２部  特２８  29頁
# 2306  2008.12.16               ［エンターテインメント］４０年前も「格差」の光景    東京朝刊   文化  19頁
# 2307  2008.10.28                ２００８年度の文化勲章・文化功労者２３人の業績    東京夕刊  夕特Ａ  16頁
# 2308  2008.09.06         ［ＢＳ・ＣＳウイークリー］「バトルスター・ギャラクティカ２」    東京朝刊  ラ都神  31頁
# 2309  2008.08.26         第３１回読売関西フォーラム（中）ものづくりで世界に躍進＝特集    大阪朝刊  朝特Ｆ  30頁
# 2310  2008.05.17               国際学生科学技術フェア　筑波大・牧野さんら特別賞    東京朝刊   ３社  33頁
# 2311  2008.04.10      京大、新薬開発ソフトのベンチャー企業設立　化学物質組み合わせピタリ    大阪朝刊   ２社  30頁
# 2312  2008.04.04            基礎からわかる「ゲームの世界」　犯罪との因果関係＝特集    東京朝刊   解説  10頁
# 2313  2008.03.26        学者マンガ家・都留泰作さん　沖縄調査体験通じ、生命の神秘に迫る    東京夕刊  夕書評  06頁
# 2314  2008.02.25        ［日本の知力］科学で考える（４）人間の直観、電脳に勝る（連載）    東京朝刊   一面  01頁
# 2315  2008.02.17           ［立体考差］「暮らす」のが一番難しい　編集委員・柴田文隆    東京朝刊  教育セ  21頁
# 2316  2008.01.25         救急患者のたらい回し防げ　岐大グループがシステム実験へ＝中部    中部朝刊  中２社  34頁
# 2317  2008.01.03         ［日本の知力］最前線で考える（１）知性、深遠なる能力（連載）    東京朝刊   一面  01頁
#
#         文字数                                               記事内容
# 0      738字  法務省は、日本の法律を効率よく英語に翻訳するため、人工知能（ＡＩ）を活用する方向で検討に入っ...
# 1     4326字  ◆新「三種の神器」　暮らし一変\n■１９９５年の期待\n私たちはインターネットの普及により、...
# 2      469字  新年の季語である嫁が君は、正月にネズミを指すときの忌み言葉で、地域によっては福の神とか、福太...
# 3      420字  ＮＴＴの澤田純社長は読売新聞のインタビューに応じ、米国で人工知能（ＡＩ）を使って都市の犯罪や...
# 4     2772字  ◇フェノックス・ベンチャー・キャピタルＣＥＯ\n◆地方政府　成長へ投資活発\n中国では今、国...
# 5     1181字  ２０１８年は日米ともに株価が乱高下した。トランプ米大統領といった要人の発言や、経済データに人...
# 6     1267字  近年、あらゆる場面で「ＡＩ（人工知能）」という言葉を見聞きするようになった。私は１９８０年代...
# 7     1523字  ◆過去データ蓄積　判断の助け\n「明日は児童相談所（児相）にとって特別な日です。失われた子ど...
# 8      787字  パナソニックの津賀一宏社長は読売新聞のインタビューに応じ、２０３０年に米国と中国での合計売上...
# 9      954字  政府主導の「官製春闘」が転換点を迎えつつある。安倍首相は２０１９年春闘で、経団連に具体的な賃...
# 10     843字  【ニューヨーク＝有光裕】米アップルが、人材獲得を全米各地に広げる戦略を進めている。成長を目指...
# 11     472字  小型衛星の製造などを行う宇宙新興企業「アクセルスペース」（東京都）は２７日午前、地球観測衛星...
# 12    1067字  ◎新聞＠スクール\n〈Ｑ〉現状に満足　夢見ない生徒\n夢を持つ生徒が少なくなっています。昔は...
# 13    2040字  作家の綿矢りささん（３４）が『蹴りたい背中』で、金原ひとみさん（３５）が『蛇にピアス』で芥川...
# 14     877字  ◇安心の設計\n２０１７年、８１歳の時に、ひな人形を飾り付けるｉＰｈｏｎｅ用のゲームアプリ「...
# 15    1184字  日本の経済界は、経団連、経済同友会、日本商工会議所という経済三団体が先導し、有力企業は、自ら...
# 16    3880字  ◎本よみうり堂\n「本よみうり堂」で書評を担当する読書委員は計２０人。２週おきに集まって読書...
# 17    5673字  ◆景気回復　続く見通し\n政府は、２０１９年度予算案で税収見積もりなどの基礎となる１９年度の...
# 18     305字  ◇深層ＮＥＷＳ\n演出家のテリー伊藤氏、人工知能研究者の黒川伊保子氏、大正大の田中俊之准教授...
# 19    1002字  第３１期竜王戦七番勝負は、「平成最後の大勝負」の第７局を制した広瀬章人（あきひと）八段（３１...
# 20     242字  ◎からだＣａｆｅ　医療と健康のページ\n１月１６日午後１時、東京・本駒込の日本医師会館大講堂...
# 21    1153字  第３１期竜王戦七番勝負は、「平成最後の大勝負」の第７局を制した広瀬章人（あきひと）八段（３１...
# 22    1026字  第３１期竜王戦七番勝負は、「平成最後の大勝負」の第７局を制した広瀬章人（あきひと）八段（３１...
# 23    2381字  ◇国際経済　Ｇｌｏｂａｌ　Ｅｃｏｎｏｍｙ\n◎編集委員　北山文裕\nインターネット上で単発の...
# 24    2162字  ◇第５部　変わる社会\n◆ＩＴの目　個人を「監視」\n中国は改革・開放政策導入から４０年を経...
# 25    1704字  ◆仕分けロボ　配達に女性活躍\n物流業界の年の瀬は、クリスマス商戦やお歳暮などが重なり、１年...
# 26    2016字  ◇ＳＣＡＮＮＥＲ\n◆通信障害など敬遠　１５％安\n携帯電話大手ソフトバンクが１９日、東京証...
# 27     645字  政府は１９日、ＩＴ総合戦略本部と官民データ活用推進戦略会議の合同会議を首相官邸で開き、新たな...
# 28     360字  日本ハムは１９日、ＮＴＴデータなどと共同で、人工知能（ＡＩ）や通信技術を駆使して養豚を効率化...
# 29    1545字  ◆愛知知事選　来月告示　人材確保策求める声も\n愛知県知事選（来年１月１７日告示、２月３日投...
# ...     ...                                                ...
# 2288   712字  ロボットに搭載する人工知能に東京大学を受験させるというプロジェクトに、国立情報学研究所（東京...
# 2289   571字  ◆テンキー付きのスマホ\nスマートフォン「ｓｍａｒｔ　ｂａｒ」（イー・アクセス）従来型の携帯...
# 2290   198字  国立大学法人・北陸先端科学技術大学院大学は３日、日本将棋連盟の米長邦雄会長を特任教授に招いて...
# 2291  1046字  ◆スパコン、クイズ王破り全米注目　特集相次ぐ\n【ワシントン＝山田哲朗】米ＩＢＭのスーパーコ...
# 2292   512字  【ワシントン＝山田哲朗】　米ＩＢＭが４年がかりで開発したスーパーコンピューター「ワトソン」が...
# 2293  1348字  ◆闘病の悩み　僕に話して\n「もしも（ｉｆ）、こんなロボットがいたらいいな」。そんな思いから...
# 2294  2945字  ◆国産探査ロボ　夢の一歩\n「地球は青かった」——。大気圏外に初めて出た旧ソ連の宇宙飛行士ユ...
# 2295  1456字  キヤノンがロボット事業に参入するのは、産業自体の急成長が見込めることに加え、自社で培った技術...
# 2296   741字  ◆異変を感知　自動的に１１９番\n精密機器大手のキヤノンが、人工知能を備えた医療・介護向けの...
# 2297  2390字  ◎Ｔｏｐ　Ｓｃｉｅｎｔｉｓｔｓ\n◆体内時計の全体像　「自分流」で解明\n「指導教官に与えら...
# 2298   415字  科学上の発見が報じられると、多くの人はこう問う。「何の役に立つの？」と。だが芸術が役に立つか...
# 2299  1124字  ◇Ｎｏ．１２５７\n「地面の雪が解けないのは土の温度が低いから。もう１回ぐらい（雪が）降るよ...
# 2300   338字  自分で状況判断して動く自律移動型ロボットにサッカーや災害救助などを行わせ、性能やプログラムの...
# 2301  1202字  恋愛下手で仕事もダメ。ヘタレ（情けない）といわれる男たちのやり場のない怒りを爆発させ、注目を...
# 2302  2632字  「笑う門には福来たる」「一笑一若」「笑いは百薬の長」などと、笑いにまつわる格言は多い。新しい...
# 2303  2036字  ◇話題作で今をみる\n新感覚の時代劇映画の公開が相次ぐ。城造りに命を懸ける宮大工や、小国の武...
# 2304  1615字  先月の２８日で、７８歳ですよ。いくらでも寝ていられる。世界中を飛び回って探訪ルポを書いていた...
# 2305  1774字  チャンネル数の多いＢＳやＣＳの場合、どの番組を見ればいいか悩んでしまう人も多いはず。特に正月...
# 2306  1491字  日本も格差社会になった、とは最近よく言われることだ。小林多喜二『蟹工船』が爆発的に売れたのも...
# 2307  4403字  （敬称略、本文記事１面）\n【文化勲章】\n◆五輪不参加バネに\n◇古橋広之進さん（元日本オ...
# 2308   386字  ◆ロボットが反乱、人類の逃避行\nＣＳ放送のスーパー！ドラマＴＶは、米メディアで「放送中のあ...
# 2309  5069字  ◆９月５日、大阪商工会議所国際会議ホールで\n関西企業の躍進が目立っている。松下電器産業やシ...
# 2310   243字  【アトランタ＝須賀幸峰】世界最大の科学コンテスト「国際学生科学技術フェア」（ＩＳＥＦ）の特別...
# 2311   404字  ◆京大准教授ら\n新薬開発の核となる化学物質の組み合わせを効率的に選び出す新手法を京都大大学...
# 2312  3764字  茨城県土浦市のＪＲ荒川沖駅周辺で３月２３日、刃物で通行人ら８人を次々に襲った無職金川真大（ま...
# 2313  1264字  沖縄の海を通して生命の神秘に迫る『ナチュン』（講談社、３巻まで）の作者、都留泰作（つるだいさ...
# 2314  3040字  ◇第２部\n２００６年１１月、長崎県西海市のホテルで、竜王戦七番勝負の第３局が行われていた。...
# 2315  1020字  女「私のこと好き？」\n男「ばか」\nこのやりとりで、２人は相思相愛とわからない人は朴念仁だ...
# 2316   843字  ◆患者の容体入力→受け入れ病院検索\n救急患者のたらい回し防止を目指し、岐阜大学医学部（岐阜...
# 2317  3376字  ◇第１部\n◆「われ思うロボット」遠い夢\n人類の歴史は多くの苦難を知力で乗り越える営みだっ...
#
# [2318 rows x 7 columns]
